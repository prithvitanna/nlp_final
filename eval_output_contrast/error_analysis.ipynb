# %% [markdown]
# ## Error Analysis

# %%
import pandas as pd
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (

# %%
contrast = pd.read_json("eval_predictions.jsonl", lines = True)

# %%
contrast
# Out:
#                                               premise  \
# 0   This church choir sings to the masses as they ...
# 1   This church choir sings to the masses as they ...
# 2   A woman with a green headscarf, blue shirt and...
# 3   A woman with a green headscarf, blue shirt and...
# 4   A woman with a green headscarf, blue shirt and...
# ..                                                ...
# 95  The tattooed basketball player is about to dun...
# 96  The tattooed basketball player is about to dun...
# 97  a boy in a red hooded top is smiling whilst lo...
# 98  A man wearing a gray ball cap walks next to a ...
# 99  An older man leans against a pedestal outside ...
#
#                                 hypothesis  label          type  \
# 0      The church is not filled with song.      2      negation
# 1             A choir singing at a church.      0  substitution
# 2             The woman is not very happy.      2      negation
# ...

# %%
contrast[contrast['predicted_label'] != contrast['label']]
# Out:
#                                               premise  \
# 4   A woman with a green headscarf, blue shirt and...
# 5   An old man with a package poses in front of an...
# 9        A land rover is being driven across a river.
# 13  A blond-haired doctor and her African american...
# 18  A young family enjoys feeling ocean waves lap ...
# 19         A couple walks hand in hand down a street.
# 23  A man reads the paper in a bar with green ligh...
# 26      Three firefighter come out of subway station.
# 27  A person wearing a straw hat, standing outside...
# 30  During a calf roping a cowboy calls off his ho...
# 32  A little boy in a gray and white striped sweat...
# 33  A woman wearing a ball cap squats down to touc...
# 40  A person dressed in a dress with flowers and a...
# 48                        A woman working long hours.
# 51  Two children, both wearing tan coats, are embr...
# 58           A guy riding a motorcycle near junk cars
# ...

# %%
contrast[contrast['predicted_label'] != contrast['label']]['label'].value_counts() / contrast['label'].value_counts()
# Out:
# 0    0.138889
# 1    0.121212
# 2    0.290323
# Name: label, dtype: float64

# %%
contrast[contrast['predicted_label'] != contrast['label']]['type'].value_counts() / contrast['type'].value_counts()
# Out:
# addition        0.096774
# negation        0.153846
# substitution    0.310345
# Name: type, dtype: float64

# %%
contrast[contrast['predicted_label'] != contrast['label']].iloc[5]
# Out:
# premise                    A couple walks hand in hand down a street.
# hypothesis                                  A couple is walking apart
# label                                                               2
# type                                                     substitution
# predicted_scores    [-0.826759099960327, 0.557555079460144, 0.2365...
# predicted_label                                                     1
# Name: 19, dtype: object
